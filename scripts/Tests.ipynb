# %%
from membranequant import *
import time
from skimage.measure import block_reduce
# %matplotlib notebook

# %%
path = 'test_datasets/dataset2_par2_neon'
paths = direcslist(path)
imgs = [load_image(p + '/af_corrected.tif') for p in paths]
rois = [np.loadtxt(p + '/ROI.txt') for p in paths]

# %%
iq1 = ImageQuant(img=imgs, roi=rois, method='GD')
iq2 = ImageQuant(img=imgs, roi=rois, method='DE')

# %%
iq1.run()
# Out:
# Iteration 1 of 2
# 100%|██████████| 500/500 [00:15<00:00, 32.57it/s]
# Iteration 2 of 2
# 100%|██████████| 500/500 [00:15<00:00, 32.89it/s]
# Time elapsed: 31.08 seconds

# %%
iq2.run()
# Out:
# Quantifying image 1 of 5
# Quantifying image 2 of 5
# Quantifying image 3 of 5
# Quantifying image 4 of 5
# Quantifying image 5 of 5
# Time elapsed: 40.45 seconds

# %%
i = 0

fig, ax = plt.subplots()
ax.plot(iq1.mems[i])
ax.plot(iq2.mems[i])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
i = 0

fig, ax = plt.subplots()
ax.imshow(imgs[i], cmap='gray')
ax.plot(iq1.roi[0][:, 0], iq1.roi[0][:, 1])
ax.plot(iq2.roi[0][:, 0], iq2.roi[0][:, 1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
res1 = iq1.compile_res()
res1
# Out:
#     Frame  Position  Membrane signal  Cytoplasmic signal
# 0       0         0     25401.762541         9268.942961
# 1       0         1     26270.275769         9176.162154
# 2       0         2     25759.744334         9254.948064
# 3       0         3     23882.871662         9231.049743
# 4       0         4     24336.926505         9192.650635
# ..    ...       ...              ...                 ...
# 95      4        95     25816.318350         8954.094343
# 96      4        96     26025.858965         9173.033301
# 97      4        97     26926.957760         9416.359418
# 98      4        98     26200.712034         9592.840008
# 99      4        99     24085.126762         9594.763461
#
# [500 rows x 4 columns]

# %%
res2 = iq2.compile_res()
res2
# Out:
#     Frame  Position  Membrane signal  Cytoplasmic signal
# 0       0         0     25418.295899         9406.782992
# 1       0         1     26047.681671         9372.858293
# 2       0         2     25720.938530         9324.538629
# 3       0         3     23343.138720         9489.881940
# 4       0         4     24319.904174         9294.844953
# ..    ...       ...              ...                 ...
# 95      4        95     25972.414330         9007.113329
# 96      4        96     26071.348975         9261.305285
# 97      4        97     27923.701166         9184.351983
# 98      4        98     26763.783606         9496.316650
# 99      4        99     24013.091372         9709.330441
#
# [500 rows x 4 columns]
