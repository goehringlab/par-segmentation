# %%
import sys
sys.path.append('../')
from membranequant import *
import time
np.random.seed(12345)
# %matplotlib notebook

# %%
path = '../data/dataset2_par2_neon'
paths = direcslist(path)[:2]
imgs = [load_image(p + '/af_corrected.tif') for p in paths]
rois = [np.loadtxt(p + '/ROI.txt') for p in paths]

# %%
iq1 = ImageQuant(img=imgs, roi=rois, method='GD')
iq2 = ImageQuant(img=imgs, roi=rois, method='DE')

# %%
iq1.run()
# Out:
# Iteration 1 of 2
# 2022-12-19 15:43:20.443174: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Iteration 2 of 2
# Time elapsed: 19.78 seconds

# %%
iq2.run()
# Out:
# Quantifying image 1 of 2
# Quantifying image 2 of 2
# Time elapsed: 20.06 seconds

# %%
i = 0

fig, ax = plt.subplots()
ax.plot(iq1.mems[i])
ax.plot(iq2.mems[i])
# Out:
# <img src="data:image/png;base64,..." width="150">

# %%
i = 0

fig, ax = plt.subplots()
ax.imshow(imgs[i], cmap='gray')
ax.plot(iq1.roi[0][:, 0], iq1.roi[0][:, 1])
ax.plot(iq2.roi[0][:, 0], iq2.roi[0][:, 1])
print(iq2.roi[0][0, 0])
# Out:
# <img src="data:image/png;base64,..." width="150">
# 286.5988590949836

# %%
res1 = iq1.compile_res()
res1
# Out:
#     Frame  Position  Membrane signal  Cytoplasmic signal
# 0       0         0     25631.147429         9235.219785
# 1       0         1     26492.326490         9145.085821
# 2       0         2     25947.174605         9234.396177
# 3       0         3     24060.706028         9220.602883
# 4       0         4     24548.354641         9174.044816
# ..    ...       ...              ...                 ...
# 95      1        95     24226.203660         8573.443650
# 96      1        96     24777.754272         8594.121641
# 97      1        97     24824.809600         8680.234139
# 98      1        98     26645.290882         8818.284563
# 99      1        99     27017.940956         9025.285716
#
# [200 rows x 4 columns]

# %%
print(res1.iloc[0])
# Out:
# Frame                     0.000000
# Position                  0.000000
# Membrane signal       25631.147429
# Cytoplasmic signal     9235.219785
# Name: 0, dtype: float64

# %%
res2 = iq2.compile_res()
res2
# Out:
#     Frame  Position  Membrane signal  Cytoplasmic signal
# 0       0         0     25636.510450         9383.178431
# 1       0         1     26773.220801         9172.514596
# 2       0         2     26095.980754         9246.185121
# 3       0         3     24212.370473         9264.069196
# 4       0         4     24855.089403         9170.779455
# ..    ...       ...              ...                 ...
# 95      1        95     24428.152059         8577.575355
# 96      1        96     24611.564816         8746.520528
# 97      1        97     24489.961423         8920.724208
# 98      1        98     26316.099946         9055.202056
# 99      1        99     27486.098654         8953.215832
#
# [200 rows x 4 columns]

# %%
iq1.plot_segmentation(jupyter=True)
# Out:
# <img src="data:image/png;base64,..." width="400">
# interactive(children=(IntSlider(value=0, description='Frame', max=1), Output()), _dom_classes=('widget-interac…
# (<Figure size 400x400 with 1 Axes>, <AxesSubplot:>)

# %%
in_notebook()
# Out:
# True

# %%
type(np.zeros([5]))
# Out:
# numpy.ndarray
